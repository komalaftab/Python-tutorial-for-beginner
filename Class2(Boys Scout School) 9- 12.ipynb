# %%
print("hello python")
# Out:
# hello python

# %%
print(123)#int
# Out:
# 123

# %%
print(12.3)#float
# Out:
# 12.3

# %%
type(12)
# Out:
# int

# %%
type(12.3)
# Out:
# float

# %% [markdown]
# # Variables

# %%
name = 'Shahzad'
print(name)
# Out:
# Shahzad

# %%
name = 'Hamza'
print(name)
# Out:
# Hamza

# %%
name = 123
type(name)
# Out:
# int

# %%
name = True
print(name)
# Out:
# True

# %%
a1 = '123'
type(a1)
# Out:
# str

# %%
a a = '21'
# Out:
#   File "<ipython-input-13-5e531d7b4a83>", line 1
#     a a = '21'
#       ^
# SyntaxError: invalid syntax

# %%
1a = 'ahsan'
# Out:
#   File "<ipython-input-16-fe71605b4eae>", line 1
#     1a = 'ahsan'
#      ^
# SyntaxError: invalid syntax

# %%
a$a = '121'
# Out:
#   File "<ipython-input-17-d2f226b6f282>", line 1
#     a$a = '121'
#      ^
# SyntaxError: invalid syntax

# %%
a1q2 = '34'
a1q2
# Out:
# '34'

# %%
True = '54'
# Out:
#   File "<ipython-input-20-e321d21ee210>", line 1
#     True = '54'
#                ^
# SyntaxError: can't assign to keyword

# %%
true = 43
true
# Out:
# 43

# %%
my_first_school_name_is = 'Happy Home'
print(my_first_school_name_is)
# Out:
# Happy Home

# %%
_ = 23
_
# Out:
# 23

# %%
father-Name = ""
# Out:
#   File "<ipython-input-24-81fcd1e3487a>", line 1
#     father-Name = ""
#                     ^
# SyntaxError: can't assign to operator

# %% [markdown]
# # Math operators

# %%
a = 2
b = 3
a+b
# Out:
# 5

# %%
a-b
# Out:
# -1

# %%
a*b
# Out:
# 6

# %%
a/b
# Out:
# 0.6666666666666666

# %%
a // b
# Out:
# 0

# %%
10 // 3
# Out:
# 3

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
c = 10
d = 3
c % d
# Out:
# 1

# %%
c + 3
# Out:
# 13

# %%
c
# Out:
# 10

# %%
c = c+3
c
# Out:
# 13

# %%
c += 5

# %%
c
# Out:
# 23

# %%
c -= 4

# %%
c
# Out:
# 19

# %%
c *= 2
c
# Out:
# 38

# %%
c /= 2
c
# Out:
# 19.0

# %%
c //=3
c
# Out:
# 2.0

# %%
(3+2)*2+5/2
# Out:
# 12.5

# %%
3 ** 2
# Out:
# 9

# %%
(3+2) * 2 + 5**2 / 2
# Out:
# 22.5

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a == b
# Out:
# False

# %% [markdown]
# # Concatenating text strings

# %%
First_name = 'Hamza '
Last_name = 'Khan'
print(First_name +" "+ Last_name)
# Out:
# Hamza  Khan

# %%
len(First_name)
# Out:
# 6

# %%
len(First_name +" "+ Last_name)
# Out:
# 11

# %%
print('abc'+123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-239ef3efce82> in <module>()
# ----> 1 print('abc'+123)
#
# TypeError: must be str, not int

# %%
a = 10
type(a)
# Out:
# int

# %%
a=str(a)

# %%
print("The number is " + a)
# Out:
# The number is 10

# %%
name = 'Ali'
age = 25
print("My name is name and my age is age")
# Out:
# My name is name and my age is age

# %%
print("My name is " + name + " and my age is " + str(age))
# Out:
# My name is Ali and my age is 25

# %% [markdown]
# # Format

# %%
name = 'ali'
age = 25
print('My name is {} and my age is {}.'.format(name,age))
# Out:
# My name is ali and my age is 25.

# %%
print('My name is {0} and my age is {1}.My name is {0} and my age is {1}.'.format(name,age))
# Out:
# My name is ali and my age is 25.My name is ali and my age is 25.

# %%
name = 'ahsan'
age = 21
print(f'My name is {name} and my age is {age}')
# Out:
# My name is ahsan and my age is 21
